# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
tmp = np.load('test/candidate22.npz')

# %%
voxel = tmp['voxel']/255
seg = tmp['seg']

# %%
for i in range(37,60,2):
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(seg[i])
    plt.subplot(1,2,2)
    plt.imshow(voxel[i])
    plt.show()
